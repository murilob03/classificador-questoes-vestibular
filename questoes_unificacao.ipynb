# %%
import pandas as pd

df = pd.read_parquet("./data/questoes_bruto.parquet")

# %%
mappings = {
    "geografia": {
        # População e dinâmica demográfica
        "Demografia": "População e Dinâmica Demográfica",
        "População": "População e Dinâmica Demográfica",
        "Migração": "População e Dinâmica Demográfica",
        "População: Etnia e Modernidade": "População e Dinâmica Demográfica",
        # Geografia Urbana
        "Urbanização": "Geografia Urbana",
        "Urbanização II": "Geografia Urbana",
        "Urbanização Brasileira": "Geografia Urbana",
        # Regiões do Brasil
        "Divisão Regional do Brasil": "Regiões do Brasil",
        "Centro-Oeste": "Regiões do Brasil",
        "Nordeste": "Regiões do Brasil",
        "Norte": "Regiões do Brasil",
        "Sudeste": "Regiões do Brasil",
        "Sul": "Regiões do Brasil",
        # Geografia Econômica
        "Geografia Econômica": "Geografia Econômica",
        "Economia Brasileira": "Geografia Econômica",
        # Geografia Cultural
        "Geografia Cultural": "Geografia Cultural",
        # Geopolítica e atualidades
        "Geopolítica": "Geopolítica e Atualidades",
        "Primavera Arabe": "Geopolítica e Atualidades",
        "Crise dos Refugiados": "Geopolítica e Atualidades",
        "Crise na Venezuela": "Geopolítica e Atualidades",
        # Geografia Física
        "Geografia física e meio-ambiente": "Geografia Física",
        "Climatologia": "Geografia Física",
        "Climatologia do Brasil": "Geografia Física",
        "El Niño": "Geografia Física",
        "Hidrografia Brasileira": "Geografia Física",
        "Geomorfologia": "Geografia Física",
        "Geomorfologia do Brasil": "Geografia Física",
        "Pedologia/Solo": "Geografia Física",
        "Geologia": "Geografia Física",
        "Eras Geológicas": "Geografia Física",
        "Escudos Cristalinos": "Geografia Física",
        "Atmosfera": "Geografia Física",
        "Litosfera": "Geografia Física",
        "Hidrosfera": "Geografia Física",
        "Biosfera": "Geografia Física",
        "BioGeografia": "Geografia Física",
        # Meio ambiente
        "Meio Ambiente": "Geografia Ambiental",
        "Geografia Ambiental I": "Geografia Ambiental",
        "Geografia Ambiental II": "Geografia Ambiental",
        "Deslizamento e enchentes": "Geografia Ambiental",
        "Geografia Agrária": "Geografia Ambiental",
        "Chuva Ácida": "Geografia Ambiental",
        # Cartografia
        "Cartografia": "Cartografia",
        # Outros temas sociais
        "Obesidade": "dropar",
    },
    "sociologia": {
        # Fundamentos e clássicos
        "Introdução ao estudo da Sociologia": "Fundamentos da Sociologia",
        "Sociologia (Vest SP)": "dropar",
        "Sociologia (Vest PR)": "dropar",
        "Auguste Comte e o Positivismo": "Fundamentos da Sociologia",
        "Emile Durkheim": "Fundamentos da Sociologia",
        "Karl Marx": "Fundamentos da Sociologia",
        "Max Weber": "Fundamentos da Sociologia",
        # Trabalho, produção e classes sociais
        "Trabalho I": "Trabalho e Sociedade",
        "Trabalho II": "Trabalho e Sociedade",
        "Divisão Social do Trabalho": "Trabalho e Sociedade",
        "Emprego e Desemprego": "Trabalho e Sociedade",
        "Modelo de Produção": "Trabalho e Sociedade",
        "Reforma trabalhista": "Trabalho e Sociedade",
        "Estratificação Social": "Trabalho e Sociedade",
        # Cidadania, política e movimentos sociais
        "Cidadania": "Cidadania e Política",
        "Democracia e Estado": "Cidadania e Política",
        "Democracia e Sociedade": "Cidadania e Política",
        "Política e Estado": "Cidadania e Política",
        "Movimentos Sociais": "Cidadania e Política",
        # Cultura e sociedade
        "Cultura": "Cultura e Sociedade",
        "Cultura e Diversidade": "Cultura e Sociedade",
        "Cultura de Massa": "Cultura e Sociedade",
        "Cultura Popular e Erudita": "Cultura e Sociedade",
        "Ideologia": "Cultura e Sociedade",
        "Pós-Modernidade e Globalização": "Cultura e Sociedade",
        "Tecnologia da Informação": "Cultura e Sociedade",
        # Questões sociais e desigualdade
        "Racismo Científico, Darwinismo Social e Eugenia": "Desigualdade e Exclusão Social",
        "Segregação Urbana": "Desigualdade e Exclusão Social",
        "Sistema prisional": "Desigualdade e Exclusão Social",
        "Violência Urbana": "Desigualdade e Exclusão Social",
    },
    "filosofia": {
        # Filosofia Temática
        "Amizade": "Filosofia Temática",
        "Bioética": "Filosofia Temática",
        "Epistemologia": "Filosofia Temática",
        "Estética": "Filosofia Temática",
        "Ética": "Filosofia Temática",
        "Dialética": "Filosofia Temática",
        "Filosofia Alemã": "Filosofia Temática",
        "Filosofia da Educação": "Filosofia Temática",
        "Filosofia da Linguagem": "Filosofia Temática",
        "Filosofia da Religião": "Filosofia Temática",
        "Filosofia das Ciências": "Filosofia Temática",
        "Filosofia Política": "Filosofia Temática",
        "Pseudociência": "Filosofia Temática",
        "Lógica": "Filosofia Temática",
        "Metafísica": "Filosofia Temática",
        "Ontológia": "Filosofia Temática",
        "Silogismo": "Filosofia Temática",
        "Teoria do Conhecimento": "Filosofia Temática",
        "Filosofia da Ciência": "Filosofia Temática",
        "Ética e Moral": "Filosofia Temática",
        # Filosofia Antiga
        "Filosofia Antiga": "Filosofia Antiga",
        "Antiga": "Filosofia Antiga",
        "Antiga - Simulado (PR)": "Filosofia Antiga",
        "Antiga - Simulado (MG)": "Filosofia Antiga",
        "Pré-socráticos": "Filosofia Antiga",
        "Pré-Socráticos": "Filosofia Antiga",
        "Sofistas": "Filosofia Antiga",
        "Sócrates": "Filosofia Antiga",
        "Socrátes": "Filosofia Antiga",
        "Platão": "Filosofia Antiga",
        "A República de Platão": "Filosofia Antiga",
        "Platonismo": "Filosofia Antiga",
        "Aristóteles": "Filosofia Antiga",
        "Aristóteles - Ética a Nicômaco": "Filosofia Antiga",
        "Mitologia": "Filosofia Antiga",
        "Helenismo": "Filosofia Antiga",
        "Epicurismo ou Hedonismo": "Filosofia Antiga",
        "Estoicismo": "Filosofia Antiga",
        "Ceticismo e Pirronismo": "Filosofia Antiga",
        "Escola Jônica ou de Mileto": "Filosofia Antiga",
        "Tales de Mileto": "Filosofia Antiga",
        "Escola Itálica ou Pitagórica": "Filosofia Antiga",
        "Escola de Éfeso (Heráclito)": "Filosofia Antiga",
        "Escola da Pluralidade": "Filosofia Antiga",
        "Escola Eleática": "Filosofia Antiga",
        "Escola Atomista (Demócrito)": "Filosofia Antiga",
        "Parmênides e Heráclito": "Filosofia Antiga",
        "Protágoras de Abdera": "Filosofia Antiga",
        "Hípias Menor de Platão:": "Filosofia Antiga",
        "Razão na Pólis Grega": "Filosofia Antiga",
        "Filosofia Clássica": "Filosofia Antiga",
        # Filosofia Medieval
        "Filosofia Medieval": "Filosofia Medieval",
        "Medieval": "Filosofia Medieval",
        "Escolástica (Tomás de Aquino)": "Filosofia Medieval",
        "Patrística (Santo Agostinho)": "Filosofia Medieval",
        # Filosofia Moderna
        "Filosofia Moderna I": "Filosofia Moderna",
        "Filosofia Moderna II": "Filosofia Moderna",
        "Moderna I": "Filosofia Moderna",
        "Moderna II": "Filosofia Moderna",
        "Moderna - Simulado (PR)": "Filosofia Moderna",
        "Empirismo": "Filosofia Moderna",
        "René Descartes": "Filosofia Moderna",
        "Immanuel Kant": "Filosofia Moderna",
        "Kant - Ética": "Filosofia Moderna",
        "Kant - Metafisica Dos Costumes": "Filosofia Moderna",
        "Jean-Jacques Rousseau": "Filosofia Moderna",
        "Nicolau Maquiavel": "Filosofia Moderna",
        "David Hume": "Filosofia Moderna",
        "Espinosa": "Filosofia Moderna",
        "Filosofia Moderna": "Filosofia Moderna",
        "Kant I": "Filosofia Moderna",
        "Kant II": "Filosofia Moderna",
        "Davi Hume": "Filosofia Moderna",
        "Francis Bacon": "Filosofia Moderna",
        "John Locke": "Filosofia Moderna",
        "Thomas Hobbes": "Filosofia Moderna",
        "Blaise Pascal": "Filosofia Moderna",
        "Voltaire": "Filosofia Moderna",
        "Descartes": "Filosofia Moderna",
        "Rousseau I": "Filosofia Moderna",
        "Rousseau II": "Filosofia Moderna",
        "Montesquieu": "Filosofia Moderna",
        "Tocqueville": "Filosofia Moderna",
        "Espinosa ou Spinoza": "Filosofia Moderna",
        "Galileu Galilei": "Filosofia Moderna",
        "Maquiavel": "Filosofia Moderna",
        "Contratualistas": "Filosofia Moderna",
        "Empirismo Britânico": "Filosofia Moderna",
        "Iluminismo": "Filosofia Moderna",
        "Positivismo": "Filosofia Moderna",
        "Racionalismo": "Filosofia Moderna",
        "Utilitarismo": "Filosofia Moderna",
        # Filosofia Contemporânea
        "Fenomenologia": "Filosofia Contemporânea",
        "Friedrich Nietzsche": "Filosofia Contemporânea",
        "Pós-estruturalismo": "Filosofia Contemporânea",
        "Modernidade": "Filosofia Contemporânea",
        "Solipsismo": "Filosofia Contemporânea",
        "Filosofia Contemporânea": "Filosofia Contemporânea",
        "Contemporânea - Simulado (PR)": "Filosofia Contemporânea",
        "Escola de Frankfurt": "Filosofia Contemporânea",
        "Existencialismo": "Filosofia Contemporânea",
        "Pós-Modernidade": "Filosofia Contemporânea",
        "Arthur Schopenhauer": "Filosofia Contemporânea",
        "Foucault": "Filosofia Contemporânea",
        "Heidegger": "Filosofia Contemporânea",
        "Hegel": "Filosofia Contemporânea",
        "Jean-Paul Sartre": "Filosofia Contemporânea",
        "Merleau-Ponty": "Filosofia Contemporânea",
        "Nietzsche": "Filosofia Contemporânea",
        "Hannah Arendt": "Filosofia Contemporânea",
        "Hans Jonas": "Filosofia Contemporânea",
        "Ludwig Wittgenstein": "dropar",
        # Outros
        "Determinismo": "dropar",
        "Kierkegaard": "dropar",
        "Max Scheler": "dropar",
        "Carl Sagan": "dropar",
        "Introdução à Filosofia": "dropar",
        "Filosofia - Simulado (MT)": "dropar",
    },
    "artes": {
        # Arte Antiga e Média
        "Arte Rupestre": "Arte Antiga e Média",
        "Arte Egípcia": "Arte Antiga e Média",
        "Arte Grega": "Arte Antiga e Média",
        "Arte Romana": "Arte Antiga e Média",
        "Arte Medieval": "Arte Antiga e Média",
        "Arte Gótica": "Arte Antiga e Média",
        "Arte na Pré-História": "Arte Antiga e Média",
        # Arte do Renascimento ao Romantismo
        "Michelangelo": "Arte do Renascimento ao Romantismo",
        "Johannes Vermeer": "Arte do Renascimento ao Romantismo",
        "Leonardo da Vinci": "Arte do Renascimento ao Romantismo",
        "Barroco Europeu": "Arte do Renascimento ao Romantismo",
        "Barroco Mineiro": "Arte do Renascimento ao Romantismo",
        "Neoclassicismo": "Arte do Renascimento ao Romantismo",
        "Pintura Flamenga": "Arte do Renascimento ao Romantismo",
        "História da Arte no Renascimento": "Arte do Renascimento ao Romantismo",
        "Romantismo": "Arte do Renascimento ao Romantismo",
        "Romantismo Alemão": "Arte do Renascimento ao Romantismo",
        "Romantismo Francês": "Arte do Renascimento ao Romantismo",
        "Romantismo Brasileiro": "Arte do Renascimento ao Romantismo",
        "Maneirismo": "Arte do Renascimento ao Romantismo",
        # Arte Moderna
        "Abstracionismo": "Arte Moderna",
        "Cubismo": "Arte Moderna",
        "Dadaísmo": "Arte Moderna",
        "Dadaísmo, Surrealismo e Futurismo": "Arte Moderna",
        "Expressionismo": "Arte Moderna",
        "Expressionismo Abstrato": "Arte Moderna",
        "Expressionismo Alemão": "Arte Moderna",
        "Expressionismo e o Fauvismo": "Arte Moderna",
        "Fauvismo": "Arte Moderna",
        "Futurismo": "Arte Moderna",
        "Impressionismo": "Arte Moderna",
        "Modernismo": "Arte Moderna",
        "Pós-Impressionismo": "Arte Moderna",
        "Ready-Made": "Arte Moderna",
        "Realismo e Naturalismo": "Arte Moderna",
        "Surrealismo": "Arte Moderna",
        "Vanguardas": "Arte Moderna",
        "Cândido Portinari": "Arte Moderna",
        "Semana de Arte Moderna": "Arte Moderna",
        "Tarsila do Amaral": "Arte Moderna",
        "Anita Malfatti": "Arte Moderna",
        # Arte Contemporânea
        "Arte Cinética": "Arte Contemporânea",
        "Arte Conceitual": "Arte Contemporânea",
        "Arte Contemporânea": "Arte Contemporânea",
        "Arte Figurativa": "Arte Contemporânea",
        "Arte Interativa": "Arte Contemporânea",
        "Arte Positivista": "Arte Contemporânea",
        "Arte Urbana": "Arte Contemporânea",
        "Arte Visual": "Arte Contemporânea",
        "Banksy": "Arte Contemporânea",
        "Body Art": "Arte Contemporânea",
        "Happening": "Arte Contemporânea",
        "Instalação": "Arte Contemporânea",
        "Intervenção": "Arte Contemporânea",
        "Land Art (Arte da Terra)": "Arte Contemporânea",
        "Minimalismo": "Arte Contemporânea",
        "Movimento Armorial": "Arte Contemporânea",
        "Concretismo e Neoconcretismo": "Arte Contemporânea",
        "Performace": "Arte Contemporânea",
        "Pop Art": "Arte Contemporânea",
        # Arquitetura e Escultura
        "Aleijadinho": "Arquitetura e Escultura",
        "Arquitetura": "Arquitetura e Escultura",
        "Arte em Cerâmica": "Arquitetura e Escultura",
        "Arte Sacra": "Arquitetura e Escultura",
        "Escultura": "Arquitetura e Escultura",
        "Manuel da Costa Ataíde": "Arquitetura e Escultura",
        "Arquitetura e Design": "Arquitetura e Escultura",
        # Arte pelo Mundo
        "Arte Africana": "Arte pelo Mundo",
        "Arte Japonesa": "Arte pelo Mundo",
        "Arte Indígena": "Arte pelo Mundo",
        "Arte Indiana": "Arte pelo Mundo",
        "Arte Belga": "Arte pelo Mundo",
        "Arte Britânica": "Arte pelo Mundo",
        "Arte Nordestina": "Arte pelo Mundo",
        "Arte Norte-Americana": "Arte pelo Mundo",
        "Arte Brasileira": "Arte pelo Mundo",
        # Música e Dança
        "Carnaval": "Música e Dança",
        "Dança Contemporânea": "Música e Dança",
        "Dança Indígena": "Música e Dança",
        "Dança Moderna": "Música e Dança",
        "Dança Populares ou Folclóricas": "Música e Dança",
        "Quadrilha": "Música e Dança",
        "Bolsa Nova": "Música e Dança",
        "Funk Nacional": "Música e Dança",
        "Cultura Hip-Hop": "Música e Dança",
        "MPB - Música Popular Brasileira": "Música e Dança",
        "Música": "Música e Dança",
        "Música Brasileira": "Música e Dança",
        "Rock and Roll": "Música e Dança",
        "Tropicalismo": "Música e Dança",
        "Cultura Hip Hop": "Música e Dança",
        "Folclore e a Dança": "Música e Dança",
        # Linguagens Artísticas
        "Afresco": "Linguagens Artísticas",
        "Cartaz, Desenho e Ilustrações": "Linguagens Artísticas",
        "Cinema": "Linguagens Artísticas",
        "Fotografia": "Linguagens Artísticas",
        "Grafismo": "Linguagens Artísticas",
        "Gravuras e Colagem": "Linguagens Artísticas",
        "HQ e Charges": "Linguagens Artísticas",
        "Iluminura": "Linguagens Artísticas",
        "Manifestações Culturais": "Linguagens Artísticas",
        "Museu a Céu Aberto": "Linguagens Artísticas",
        "Pintura Mural": "Linguagens Artísticas",
        "Cinema e Televisão": "Linguagens Artísticas",
        # Artes Cênicas
        "Teatro": "Teatro",
        "Teatro do Oprimido": "Teatro",
        # Outros
        "Afro-Cultura": "dropar",
        "Artes (SP)": "dropar",
    },
    "portugues": {
        # Interpretação
        "Texto Dissertativo (Argumentativo e Expositivo)": "Interpretação",
        "Elementos Textuais e Função Social": "Interpretação",
        "Elementos Textuais e Função Social II": "Interpretação",
        "Estratégias Argumentativas": "Interpretação",
        "Estratégias Argumentativas II": "Interpretação",
        "Interpretação de Texto": "Interpretação",
        "Interpretação de Texto II": "Interpretação",
        "Intertextualidade": "Interpretação",
        "Intertextualidade II": "Interpretação",
        "Narração e Descrição": "Interpretação",
        "Narração e Descrição II": "Interpretação",
        "Poesia e Poema": "Interpretação",
        "Texto Não Literário": "Interpretação",
        "Texto Não Literário II": "Interpretação",
        "Tecnologia da Informação": "Interpretação",
        "Tecnologia da Informação II": "Interpretação",
        "Crônica": "Interpretação",
        "Artigo de Opinião": "Interpretação",
        "Diário": "Interpretação",
        "Reportagem": "Interpretação",
        "Texto Argumentativo": "Interpretação",
        # Estilística
        "Figuras de Linguagem": "Estilística",
        "Figuras de Linguagem II": "Estilística",
        "Funções da Linguagem": "Estilística",
        "Construção e Efeito de Sentido": "Estilística",
        # Gramática
        "Gramática": "Gramática",
        "Coesão Textual": "Gramática",
        "Acentuação Gráfica": "Gramática",
        "Crase": "Gramática",
        "Sinais de Pontuação": "Gramática",
        "Uso da Vírgula": "Gramática",
        # Sintaxe (itens antes em Concordância/Regência)
        "Concordância Nominal": "Sintaxe",
        "Concordância Verbal e Nominal": "Sintaxe",
        "Concordância Verbal": "Sintaxe",
        "Regência Nominal": "Sintaxe",
        "Regência Verbal": "Sintaxe",
        # Morfologia (itens antes em Classes Gramaticais / Gramática)
        "Adjetivos": "Morfologia",
        "Artigo": "Morfologia",
        "Conjunção": "Morfologia",
        "Interjeição": "Morfologia",
        "Numeral": "Morfologia",
        "Preposição": "Morfologia",
        "Pronomes": "Morfologia",
        "Substantivos": "Morfologia",
        "Verbos": "Morfologia",
        # Sociolinguística
        "Língua e Linguagem": "Sociolinguística",
        "Língua e Linguagem II": "Sociolinguística",
        "Variação Linguística e Patrimônio Linguístico": "Sociolinguística",
        "Variação Linguística e Patrimônio Linguístico II": "Sociolinguística",
        "Línguas Indígenas": "Sociolinguística",
        "Sistemas de Comunicação": "Sociolinguística",
        "Linguagem Não-Verbal": "Sociolinguística",
        # Educação Física
        "Educação Física": "Educação Física",
        "Práticas Corporais e Autonomia": "Educação Física",
        "Padrão Estético Contemporâneo": "Educação Física",
        "Esportes": "Educação Física",
        "Exercício Físico e Saúde": "Educação Física",
        "Corpo e Expressão Artística/Cultural": "Educação Física",
        "Danças": "Educação Física",
        "Condicionamentos e Esforços Físicos": "Educação Física",
        "Lutas": "Educação Física",
        "Jogos e Brincadeiras": "Educação Física",
    },
    "literatura": {
        # Literatura Medieval
        "Trovadorismo": "Literatura Medieval",
        "Humanismo": "Literatura Medieval",
        "Classicismo": "Literatura Medieval",
        "Gil Vicente": "Literatura Medieval",
        "Ilíada e a Odisseia, Homero": "Literatura Medieval",
        # Quinhentismo
        "Quinhentismo I": "Quinhentismo",
        "Quinhentismo II": "Quinhentismo",
        "Carta de Achamento do Brasil, Pero Vaz de Caminha": "Quinhentismo",
        "José de Anchieta (Auto de São Lourenço)": "Quinhentismo",
        # Barroco
        "Barroco (1601)": "Barroco",
        "Padre Antônio Vieira": "Barroco",
        "“Sermão do Mandato”, de Antônio Vieira": "Barroco",
        "Gregório de Matos": "Barroco",
        "Antologia, Gregório De Matos": "Barroco",
        "Poemas Escolhidos, Gregório de Matos": "Barroco",
        # Arcadismo
        "Arcadismo (1756)": "Arcadismo",
        "Caramuru, de Frei de Santa Rita Durão": "Arcadismo",
        "Cartas Chilenas, Tomás Antônio Gonzaga": "Arcadismo",
        "Cláudio Manuel da Costa": "Arcadismo",
        "Marília de Dirceu e Cartas Chilenas, de Tomás Antônio Gonzaga": "Arcadismo",
        "Marília de Dirceu, de Tomás Antônio Gonzaga": "Arcadismo",
        "O Uraguai, Basílio da Gama": "Arcadismo",
        "Marquesa de Alorna": "Arcadismo",
        # Romantismo
        "Romantismo": "Romantismo",
        "Romantismo (1836)": "Romantismo",
        "Romantismo - (Vest SP)": "Romantismo",
        "Fagundes Varela": "Romantismo",
        "Amor de perdição, Camilo Castelo Branco": "Romantismo",
        "Lucíola, de José de Alencar": "Romantismo",
        "Úrsula, Maria Firmina dos Reis": "Romantismo",
        "Memórias de um Sargento de Milícias, Manuel Antônio de Almeida": "Romantismo",
        "A Última Quimera, Ana Miranda": "Romantismo",
        "Boca Do Inferno, Ana Miranda": "Romantismo",
        # Realismo e Naturalismo
        "Realismo e Naturalismo": "Realismo e Naturalismo",
        "Realismo I": "Realismo e Naturalismo",
        "Realismo II": "Realismo e Naturalismo",
        "Naturalismo": "Realismo e Naturalismo",
        "Conto Marcha Fúnebre, de Machado de Assis": "Realismo e Naturalismo",
        "Troca de datas, de Machado de Assis": "Realismo e Naturalismo",
        "Machado de Assis": "Realismo e Naturalismo",
        "Dom Casmurro, Machado de Assis": "Realismo e Naturalismo",
        "O Ateneu, de Raul Pompeia": "Realismo e Naturalismo",
        "O Cortiço, Aluísio de Azevedo": "Realismo e Naturalismo",
        "Casa de pensão, Aluísio Azevedo": "Realismo e Naturalismo",
        "Esaú e Jacó, Machado de Assis": "Realismo e Naturalismo",
        "Memórias Póstumas de Brás Cubas, Machado de Assis": "Realismo e Naturalismo",
        "O Alienista, Machado de Assis": "Realismo e Naturalismo",
        "Quincas Borba, Machado de Assis": "Realismo e Naturalismo",
        "A Falência, Júlia Lopes De Almeida": "Realismo e Naturalismo",
        "Realismo e Naturalismo - (Vest SP)": "Realismo e Naturalismo",
        # Parnasianismo e Simbolismo
        "Olavo Bilac": "Parnasianismo e Simbolismo",
        "O Filtro da Leitura, de Luís Augusto Fischer": "Parnasianismo e Simbolismo",
        "Parnasianismo I": "Parnasianismo e Simbolismo",
        "Parnasianismo II": "Parnasianismo e Simbolismo",
        "Simbolismo I": "Parnasianismo e Simbolismo",
        "Simbolismo II": "Parnasianismo e Simbolismo",
        "Simbolismo e o Parnasianismo": "Parnasianismo e Simbolismo",
        "Parnasianismo e Simbolismo (Vest SP)": "Parnasianismo e Simbolismo",
        # Modernismo
        "Modernismo I": "Modernismo",
        "Modernismo II": "Modernismo",
        "Modernismo (Vest SP)": "Modernismo",
        "Pré-Modernismo": "Modernismo",
        "Primeira Fase do Modernismo I": "Modernismo",
        "Segunda Fase do Modernismo II": "Modernismo",
        "Terceira Fase do Modernismo I": "Modernismo",
        "Terceira Fase do Modernismo II": "Modernismo",
        "Vida e morte de M. J. Gonzaga de Sá, de Lima Barreto": "Modernismo",
        "Lima Barreto": "Modernismo",
        "Clara dos Anjos, Lima Barreto": "Modernismo",
        "Triste fim de Policarpo Quaresma, Lima Barreto": "Modernismo",
        "Mensagem: Fernando Pessoa": "Modernismo",
        "Macunaíma - Mário de Andrade": "Modernismo",
        "Pauliceia Desvairada - Mário de Andrade": "Modernismo",
        "Contos Novos, Mário de Andrade": "Modernismo",
        "Memórias do Cárcere, Graciliano Ramos": "Modernismo",
        "São Bernardo, de Graciliano Ramos": "Modernismo",
        "Angústia, Graciliano Ramos": "Modernismo",
        "Vidas Secas, Graciliano Ramos": "Modernismo",
        "Carlos Drummond de Andrade": "Modernismo",
        "Caminhos de João Brandão": "Modernismo",
        "A Rosa do Povo": "Modernismo",
        "Alguma Poesia": "Modernismo",
        "Claro Enigma": "Modernismo",
        "Capitães da Areia, de Jorge Amado": "Modernismo",
        "Conto Cruel, de Mário Quintana": "Modernismo",
        "Romanceiro da Inconfidência, de Cecília Meireles": "Modernismo",
        "Érico Veríssimo": "Modernismo",
        "José Lins do Rêgo": "Modernismo",
        "Mario Quintana": "Modernismo",
        "Clarice Lispector": "Modernismo",
        "A Legião Estrangeira": "Modernismo",
        "Amor e Amizade": "Modernismo",
        "A hora da Estrela": "Modernismo",
        "Sagarana": "Modernismo",
        "Campo Geral": "Modernismo",
        "O Santo e a Porca": "Modernismo",
        "Auto da Compadecida": "Modernismo",
        "Morte e Vida Severina, João Cabral de Melo Neto": "Modernismo",
        "Amar, Verbo Intransitivo, Mário De Andrade": "Modernismo",
        "Lygia Fagundes": "Modernismo",
        # Literatura Contemporânea
        "Literatura Contemporânea": "Literatura Contemporânea",
        "Um Gênero Tipicamente Brasileiro, Humberto Werneck": "Literatura Contemporânea",
        "Dois irmãos, de Milton Hatoum": "Literatura Contemporânea",
        "O Avesso da Pele, de Jeferson Tenório": "Literatura Contemporânea",
        "Relato de um Certo Oriente, de Milton Hatoum": "Literatura Contemporânea",
        "Nove Noites, de Bernardo Carvalho": "Literatura Contemporânea",
        "Banquete com os Deuses, Luis Fernando Verissimo": "Literatura Contemporânea",
        "João Ubaldo Ribeiro": "Literatura Contemporânea",
        "Luiz Ruffato": "Literatura Contemporânea",
        "Adélia Prado": "Literatura Contemporânea",
        "Jessé Souza": "Literatura Contemporânea",
        "Gonçalo M. Tavares": "Literatura Contemporânea",
        # Itens para dropar
        "Período Colonial": "dropar",
        "Barroco e Arcadismo (Vest SP)": "dropar",
        "O Crime do Padre Amaro": "dropar",
        "As Cidades e as Serras": "dropar",
        "O Primo Basílio": "dropar",
        "A Ilustre Casa De Ramires, Eça De Queirós": "dropar",
        "Alice no País das Maravilhas, de Lewis Carrol": "dropar",
        "1984, George Orwell": "dropar",
        "A Metamorfose, Franz Kafka": "dropar",
        "A Vida De Galileu, Bertolt Brecht": "dropar",
        "Tratado Da maneira de Distinguir o Bajulador do Amigo, Plutarco": "dropar",
        "Racionais": "dropar",
        "A Queda do Céu: Palavras de uma Xamã Yanomami, de Davi Kopenawa e Bruce Albert": "dropar",
        "Quarto de Despejo, Carolina Maria de Jesus": "dropar",
        "Minha Vida de Menina, Helena Morley": "dropar",
        "Peça A falecida, Nelson Rodrigues": "dropar",
        "O Teatro Mágico": "dropar",
        "Eles não usam black-tie, Gianfrancesco Guarnieri": "dropar",
        "Futurismo": "dropar",
        "Impressionismo": "dropar",
        # Literatura Africana
        "Literatura Angolana": "Literatura Africana",
        "Literatura Moçambicana": "Literatura Africana",
        "Luuanda, de José Luandino Vieira": "Literatura Africana",
        "Os da Minha Rua, de Ondjaki": "Literatura Africana",
        "Pepetela": "Literatura Africana",
        "Balada de Amor ao Vento, Paulina Chiziane": "Literatura Africana",
        "Estórias Abensonhadas, Mia Couto": "Literatura Africana",
        "Luís Bernardo Honwana": "Literatura Africana",
        "Nós Matamos o Cão Tinhoso, Luis Bernardo Honwana": "Literatura Africana",
        "O Fio das Missangas, de Mia Couto": "Literatura Africana",
        "Paulina Chiziane": "Literatura Africana",
        "Terra Sonâmbula, Mia Couto": "Literatura Africana",
        "Mia Couto": "Literatura Africana",
        "Chimamanda Ngozi Adichie": "Literatura Africana",
    },
    "idiomas": {
        "Língua Espanhola I": "Espanhol",
        "Língua Espanhola II": "Espanhol",
        "Língua Inglesa I": "Inglês",
        "Língua Inglesa II": "Inglês",
        "Língua Inglesa: Enem 2019": "Inglês",
        "Língua Inglesa: Enem 2018": "Inglês",
        "Língua Inglesa: Enem 2017": "Inglês",
        "Língua Inglesa: Enem 2016": "Inglês",
        "Língua Inglesa: Enem 2015": "Inglês",
        "Língua Inglesa: Enem 2014": "Inglês",
        "Língua Inglesa: Enem 2013": "Inglês",
        "Língua Inglesa: Enem 2012": "Inglês",
        "Língua Espanhola: Enem 2019": "Espanhol",
        "Língua Espanhola: Enem 2018": "Espanhol",
        "Língua Espanhola: Enem 2017": "Espanhol",
        "Língua Espanhola: Enem 2016": "Espanhol",
        "Língua Espanhola: Enem 2015": "Espanhol",
        "Língua Espanhola: Enem 2014": "Espanhol",
        "Língua Espanhola: Enem 2013": "Espanhol",
        "Língua Espanhola: Enem 2012": "Espanhol",
        "Língua Espanhola: Enem 2011": "Espanhol",
        "Língua Espanhola: Enem 2010": "Espanhol",
        "Inglês - Adjetivos": "Inglês",
        "Inglês - Preposição": "Inglês",
        "Inglês - Substantivos": "Inglês",
        "Inglês - Verbos": "Inglês",
        "Espanhol - Simulado (0 Listas) - (MT)": "Espanhol",
        "Inglês - AFA": "Inglês",
        "Inglês - CN": "Inglês",
        "Inglês - EEAR": "Inglês",
        "Inglês - EPCAR": "Inglês",
    },
    "historia": {
        # Pré-História
        "Pré-História": "Pré-História",
        "Pré-História I": "Pré-História",
        "Pré-História II": "Pré-História",
        # Idade Antiga Oriental
        "Antiguidade Oriental": "Idade Antiga Oriental",
        "Egito Antigo": "Idade Antiga Oriental",
        "Mesopotâmia": "Idade Antiga Oriental",
        "Fenícios": "Idade Antiga Oriental",
        "Hebreus": "Idade Antiga Oriental",
        "Persas": "Idade Antiga Oriental",
        "Assírios": "Idade Antiga Oriental",
        "Código de Hamurábi": "Idade Antiga Oriental",
        "Hititas ou Heteus": "Idade Antiga Oriental",
        "Império Babilônico": "Idade Antiga Oriental",
        "Sumérios": "Idade Antiga Oriental",
        # Grécia Antiga
        "Grécia Antiga": "Grécia Antiga",
        "Alexandre, o Grande - Macedônia": "Grécia Antiga",
        "Atenas": "Grécia Antiga",
        "Cidades-estado": "Grécia Antiga",
        "Democracia grega": "Grécia Antiga",
        "Esparta": "Grécia Antiga",
        "Guerra do Peloponeso": "Grécia Antiga",
        "Guerras Médicas": "Grécia Antiga",
        "Jogos Olímpicos": "Grécia Antiga",
        "Liga do Peloponeso e de Delos": "Grécia Antiga",
        "Período Clássico": "Grécia Antiga",
        "Mitologia": "Grécia Antiga",
        "Período Helenístico": "Grécia Antiga",
        "Período Homérico e Arcaico": "Grécia Antiga",
        "Religião Grega": "Grécia Antiga",
        # Roma Antiga
        "Roma Antiga": "Roma Antiga",
        "Cidadania Romana": "Roma Antiga",
        "Exército Romano": "Roma Antiga",
        "Guerras Púnicas": "Roma Antiga",
        "Invasões Bárbaras": "Roma Antiga",  # Relacionado à queda de Roma
        "Júlio Cesar e Otávio Augusto": "Roma Antiga",
        "República Romana": "Roma Antiga",
        # Início da Idade Média
        "Alta Idade Média": "Idade Média",
        "Povos Bárbaros ou Povos Germânicos": "Idade Média",
        # Feudalismo e Igreja Católica
        "Baixa Idade Média": "Idade Média",
        "Feudalismo": "Idade Média",
        "Cruzadas": "Idade Média",
        "Guerra dos Cem Anos": "Idade Média",
        # Renascimento Carolíngio e Reforma
        "Império Carolíngio e Carlos Magno": "Idade Média",
        # Renascimento
        "Renascimento": "Idade Média",
        "Idade Média": "Idade Média",
        "Idade Média I": "Idade Média",
        "Idade Média II": "Idade Média",
        "Idade Média III": "Idade Média",
        "Idade Média IV": "Idade Média",
        "Idade Média (Vest SP)": "Idade Média",
        "Império Bizantino": "Idade Média",
        "Povos Árabes": "Idade Média",
        "Origem e Expansão do Islã": "Idade Média",
        # Revoluções e Reforma
        "Iluminismo": "Idade Moderna: Revoluções e Reforma",
        "Reformas Religiosas": "Idade Moderna: Revoluções e Reforma",
        "Reforma Protestante": "Idade Moderna: Revoluções e Reforma",
        "Revolução Inglesa": "Idade Moderna: Revoluções e Reforma",
        "Revoluções Inglesas": "Idade Moderna: Revoluções e Reforma",
        "Era Napoleônica": "Idade Moderna: Revoluções e Reforma",
        "Revolução Francesa": "Idade Moderna: Revoluções e Reforma",
        # Expansão Marítima e Formação dos Estados Nacionais
        "Absolutismo": "Expansão Marítima e Formação dos Estados Nacionais",
        "Antigo Regime": "Expansão Marítima e Formação dos Estados Nacionais",
        "Expansão Marítima e Mercantilismo": "Expansão Marítima e Formação dos Estados Nacionais",
        "Formação do Estado": "Expansão Marítima e Formação dos Estados Nacionais",
        "Expansão Marítima Europeia (Fuvest)": "Expansão Marítima e Formação dos Estados Nacionais",
        "Absolutismo Francês": "Expansão Marítima e Formação dos Estados Nacionais",
        "Absolutismo Inglês": "Expansão Marítima e Formação dos Estados Nacionais",
        # Revoluções Industriais
        "Revolução Industrial": "Revoluções Industriais",
        "Sistema e Modelos de Produção": "Revoluções Industriais",
        "Ludismo e Cartismo": "Revoluções Industriais",
        # Guerras Mundiais
        "Primeira Guerra Mundial": "Guerras Mundiais",
        "Segunda Guerra Mundial": "Guerras Mundiais",
        "Regimes Totalitários": "Guerras Mundiais",
        "Regimes totalitários": "Guerras Mundiais",
        "Crise de 1929": "Guerras Mundiais",
        "Revolução Russa": "Guerras Mundiais",
        "Fascismo": "Guerras Mundiais",
        "Franquismo": "Guerras Mundiais",
        "Salazarismo": "Guerras Mundiais",
        "Nazismo": "Guerras Mundiais",
        "Conferência de Paris": "Guerras Mundiais",
        "Tratado de Versalhes": "Guerras Mundiais",
        # Guerra Fria e Globalização
        "Guerra Fria": "Guerra Fria e Globalização",
        "Descolonização Afro-asiática": "Guerra Fria e Globalização",
        "Apartheid na África do Sul": "Guerra Fria e Globalização",
        "Independência Da Índia": "Guerra Fria e Globalização",
        "Movimento Hippie Contracultura": "Guerra Fria e Globalização",
        "Questão Árabe": "Guerra Fria e Globalização",
        "Sociedade e Direitos Humanos": "Guerra Fria e Globalização",
        "Fim da URSS": "Guerra Fria e Globalização",
        "Guerra da Coreia": "Guerra Fria e Globalização",
        "Guerra Do Vietnã": "Guerra Fria e Globalização",
        "Revolução Chinesa": "Guerra Fria e Globalização",
        "Revolução dos Cravos": "Guerra Fria e Globalização",
        "Conflito árabe-israelense": "Guerra Fria e Globalização",
        "Conflitos no Líbano, Irã e Iraque": "Guerra Fria e Globalização",
        "Conflitos no Oriente Médio": "Guerra Fria e Globalização",
        "Primavera de Praga": "Guerra Fria e Globalização",
        "Revolução Islâmica": "Guerra Fria e Globalização",
        "Guerra da Síria": "Guerra Fria e Globalização",
        "Península/Anexação da Criméia": "Guerra Fria e Globalização",
        # Brasil Colônia (1500-1822)
        "Brasil Colônia": "Brasil Colônia",
        "Brasil Colônia II": "Brasil Colônia",
        "Brasil Colônia (Vest SP)": "Brasil Colônia",
        "Brasil Colônia I": "Brasil Colônia",
        "Brasil Colônia III": "Brasil Colônia",
        "Brasil Colônia IV": "Brasil Colônia",
        "Brasil Colônia V": "Brasil Colônia",
        "Capitanias Hereditárias": "Brasil Colônia",
        "Entradas e Bandeiras": "Brasil Colônia",
        "Família Real Portuguesa": "Brasil Colônia",
        "Invasões Holandesas": "Brasil Colônia",
        "Jesuítas": "Brasil Colônia",
        "Período Joanino": "Brasil Colônia",
        "Religião no Brasil Colônia": "Brasil Colônia",
        "Revoltas no Brasil Colônia": "Brasil Colônia",
        "Sociedade no Brasil Colônia": "Brasil Colônia",
        "Chegada dos Portugueses ao Brasil": "Brasil Colônia",
        "Período Pré-Colonial": "Brasil Colônia",
        "Pau Brasil": "Brasil Colônia",
        "Pedro Álvares Cabral": "Brasil Colônia",
        "Pero Vaz de Caminha": "Brasil Colônia",
        "Martim Afonso de Sousa": "Brasil Colônia",
        "Carta de Doação e Foral": "Brasil Colônia",
        "Lei das Sesmarias": "Brasil Colônia",
        "Capitania de São Vicente": "Brasil Colônia",
        "Capitania de Pernambuco": "Brasil Colônia",
        "Capitania de Itamaracá:": "Brasil Colônia",
        "Capitania de Minas Gerais": "Brasil Colônia",
        "Capitania de Mato Grosso": "Brasil Colônia",
        "Capitania de Goiás": "Brasil Colônia",
        "Capitania do Maranhão": "Brasil Colônia",
        "Capitania do Rio Negro": "Brasil Colônia",
        "Marquês de Pombal": "Brasil Colônia",
        "Governo Geral": "Brasil Colônia",
        "Expansão Territorial Da Colônia": "Brasil Colônia",
        "Estado do Grão-Pará e Maranhão": "Brasil Colônia",
        "Tratado de Limites": "Brasil Colônia",
        "Tratado de Tordesilhas (1494)": "Brasil Colônia",
        "Tratado de Madrid (1750)": "Brasil Colônia",
        "Tratado de Methuen": "Brasil Colônia",
        "Tratado de Fontainebleau": "Brasil Colônia",
        "Economia Colonial: Açúcar": "Brasil Colônia",
        "Economia Colonial: Mineração": "Brasil Colônia",
        "Plantation": "Brasil Colônia",
        "Ciclo do Ouro": "Brasil Colônia",
        "Quinto do Ouro e Casas de Fundição": "Brasil Colônia",
        "Pacto Colonial (Exclusivo Metropolitano)": "Brasil Colônia",
        "Companhia Geral de Comércio do Grão-Pará e Maranhão": "Brasil Colônia",
        "Quilombo dos Palmares": "Brasil Colônia",
        "Domínio Espanhol e Brasil Holandês": "Brasil Colônia",
        "União Ibérica | Invasão Holandesa": "Brasil Colônia",
        "Estado e Religião No Brasil Colônia": "Brasil Colônia",
        "Primeira Missa no Brasil": "Brasil Colônia",
        "Política de Aldeamentos": "Brasil Colônia",
        "Padre Antônio Vieira": "Brasil Colônia",
        "Manoel da Nóbrega e José de Anchieta": "Brasil Colônia",
        "Guerra dos Emboabas": "Brasil Colônia",
        "Guerra dos Mascates": "Brasil Colônia",
        "Revolta de Beckman": "Brasil Colônia",
        "Revolta Felipe dos Santos": "Brasil Colônia",
        "Revoltas Nativistas": "Brasil Colônia",
        "Revoltas Separatistas": "Brasil Colônia",
        "Aclamação de Amador Bueno": "Brasil Colônia",
        "Escravidão e Resistência": "Brasil Colônia",
        "Navio Negreiro": "Brasil Colônia",
        # Brasil Império (1822-1889)
        "Brasil Império": "Brasil Império",
        "Brasil Império I": "Brasil Império",
        "Brasil Império II": "Brasil Império",
        "Brasil Império III": "Brasil Império",
        "Brasil Império IV": "Brasil Império",
        "Brasil Império V": "Brasil Império",
        "Brasil Império (Vest SP)": "Brasil Império",
        "Primeiro Reinado": "Brasil Império",
        "Período Regencial": "Brasil Império",
        "Segundo Reinado": "Brasil Império",
        "Independência Do Brasil I": "Brasil Império",
        "Independência Do Brasil II": "Brasil Império",
        "Abdicação de D. Pedro I": "Brasil Império",
        "Confederação do Equador (1824)": "Brasil Império",
        "Primeira Constituição (1824)": "Brasil Império",
        "Impressa no Primeiro Reinado": "Brasil Império",
        "Primeiro Reinado (fuvest)": "Brasil Império",
        "Primeiro Reinado I": "Brasil Império",
        "Primeiro Reinado II": "Brasil Império",
        "Período Regencial (Fuvest)": "Brasil Império",
        "Período Regencial I": "Brasil Império",
        "Cabanagem": "Brasil Império",
        "Guerra dos Farrapos I": "Brasil Império",
        "Revolução Farroupilha II": "Brasil Império",
        "Revolta dos Malês e Sabinada": "Brasil Império",
        "Revoltas no Período Regencial": "Brasil Império",
        "Guarda Nacional": "Brasil Império",
        "Noite das Garrafadas": "Brasil Império",
        "Segundo Reinado 1840-1889": "Brasil Império",
        "Fim Do Império": "Brasil Império",
        "Guerra do Paraguai": "Brasil Império",
        "Revolução Praieira": "Brasil Império",
        "Bill Aberdeen": "Brasil Império",
        "Joaquim Nabuco": "Brasil Império",
        "Lei Áurea": "Brasil Império",
        "Lei de Terras": "Brasil Império",
        "Lei do Ventre Livre": "Brasil Império",
        "Lei dos Sexagenários": "Brasil Império",
        "Lei Eusébio de Queirós": "Brasil Império",
        "Movimento Abolicionista": "Brasil Império",
        "Tráfico Negreiro no Brasil": "Brasil Império",
        "Barão de Maua": "Brasil Império",
        "Café no vale do Paraíba": "Brasil Império",
        "Economia do Império do Brasil": "Brasil Império",
        "Imigração no Segundo Reinado": "Brasil Império",
        "Questão Christie": "Brasil Império",
        "Tarifa Alves Branco": "Brasil Império",
        # Brasil República (1889-Hoje)
        "Brasil República": "Brasil República",
        "Brasil República II": "Brasil República",
        "Brasil República I": "Brasil República",
        "Brasil República III": "Brasil República",
        "Brasil República IV": "Brasil República",
        "Brasil República V": "Brasil República",
        "Brasil República (Vest SP)": "Brasil República",
        "Era Vargas": "Brasil República",
        "Ditadura Militar": "Brasil República",
        "República Velha": "Brasil República",
        "Nova República": "Brasil República",
        "Proclamação da República I (1889)": "Brasil República",
        "Proclamação da República II (1889)": "Brasil República",
        "Constituição de 1891": "Brasil República",
        "Governo do Marechal Deodoro": "Brasil República",
        "Governo do Floriano Peixoto": "Brasil República",
        "República da Espada I (1889-1894)": "Brasil República",
        "República da Espada II (1889-1894)": "Brasil República",
        "Coluna Prestes": "Brasil República",
        "Guerra do Contestado": "Brasil República",
        "Movimento Tenentista": "Brasil República",
        "Revolta do Forte ou 18 do Forte": "Brasil República",
        "Revolta Paulista de 1924": "Brasil República",
        "Revoltas Na Primeira República": "Brasil República",
        "Cangaço": "Brasil República",
        "Greve de 1917": "Brasil República",
        "Guerra de Canudos": "Brasil República",
        "Revolta da Vacina": "Brasil República",
        "Revolução de 1923": "Brasil República",
        "Revolução Federalista": "Brasil República",
        "Sedição de Juazeiro": "Brasil República",
        "Coronelismo": "Brasil República",
        "Política dos Governadores": "Brasil República",
        "República Oligárquica (1894-1930)": "Brasil República",
        "República Velha (1889-1930)": "Brasil República",
        "Ciclo da Borracha": "Brasil República",
        "Era Vargas (Mackenzie)": "Brasil República",
        "Era Vargas I (1930-1945)": "Brasil República",
        "Era Vargas II (1930-1945)": "Brasil República",
        "República Populista I (1945 a 1964)": "Brasil República",
        "República Populista II (1945 a 1964)": "Brasil República",
        "Governo JK (1956 a 1961)": "Brasil República",
        "Governos Militares I (1964-1985)": "Brasil República",
        "Governos Militares II (1964-1985)": "Brasil República",
        "Governos Militares (Fuvest)": "Brasil República",
        "Nova República I (1985 a hoje)": "Brasil República",
        "Nova República II (1985 a hoje)": "Brasil República",
        "Revolta da Chibata": "Brasil República",  # Ocorrida em 1910
        # 1. América Pré-Colombiana
        "Império Asteca": "América Pré-Colombiana",
        "Império Inca": "América Pré-Colombiana",
        "Império Maia": "América Pré-Colombiana",
        "Civilizações Pré-Colombianas": "América Pré-Colombiana",
        # 2. Colonização e Independência das Américas
        "Colonização da América Inglesa": "Colonização e Independência das Américas",
        "Independência dos Estados Unidos": "Colonização e Independência das Américas",
        "América Espanhola": "Colonização e Independência das Américas",
        "Revolução Haitiana": "Colonização e Independência das Américas",
        "Simón Bolívar": "Colonização e Independência das Américas",
        "Indepe. da América Espanhola": "Colonização e Independência das Américas",
        "Colonização Francesa nas Américas": "Colonização e Independência das Américas",
        "França Antártica": "Colonização e Independência das Américas",
        "França Equinocial": "Colonização e Independência das Américas",
        # 3. Formação dos EUA e Imperialismo
        "Guerra de Secessão": "Formação dos EUA e Imperialismo",
        "Doutrina Monroe": "Formação dos EUA e Imperialismo",
        "Big Stick": "Formação dos EUA e Imperialismo",
        # 4. América Latina Contemporânea
        "História da América": "América Latina Contemporânea",  # Genérico, melhor aqui
        "América Latina": "América Latina Contemporânea",
        "Revolução Cubana": "América Latina Contemporânea",
        "Revolução Mexicana": "América Latina Contemporânea",
        "Revolução Mexicana (Fuvest)": "América Latina Contemporânea",
        "Revolução Sandinista": "América Latina Contemporânea",
        "América Contemporânea": "América Latina Contemporânea",
        "Ditaduras Na América Latina: Século XX": "América Latina Contemporânea",
        "Guerra das Malvinas": "América Latina Contemporânea",
        "Peronismo": "América Latina Contemporânea",
        # 5. Reinos e Impérios Africanos
        "Impérios africanos": "Reinos e Impérios Africanos",
        "Império de Kush": "Reinos e Impérios Africanos",
        "Império do Congo": "Reinos e Impérios Africanos",
        "Império do Mali": "Reinos e Impérios Africanos",
        "Njinga: Ndongo e de Matamba": "Reinos e Impérios Africanos",
        "Reino de Axum": "Reinos e Impérios Africanos",
        "Reino de Gana": "Reinos e Impérios Africanos",
        "Reinos Bantos": "Reinos e Impérios Africanos",
        "Religião na África": "Reinos e Impérios Africanos",  # Contexto cultural
        # 6. Século XIX: Nacionalismo e Imperialismo
        "Comuna de Paris": "Século XIX: Nacionalismo e Imperialismo",
        "Colonialismo e Imperialismo": "Século XIX: Nacionalismo e Imperialismo",
        "Neocolonialismo ou Imperialismo": "Século XIX: Nacionalismo e Imperialismo",
        "Congresso de Viena": "Século XIX: Nacionalismo e Imperialismo",
        "Conferência de Berlim": "Século XIX: Nacionalismo e Imperialismo",
        "Guerra Franco-Prussiana": "Século XIX: Nacionalismo e Imperialismo",
        "Guerras do Ópio": "Século XIX: Nacionalismo e Imperialismo",
        "Colonialismo": "Século XIX: Nacionalismo e Imperialismo",
        "Primavera dos Povos": "Século XIX: Nacionalismo e Imperialismo",
        "Unificação da Alemanha e da Itália": "Século XIX: Nacionalismo e Imperialismo",
        "Guerra da Criméia": "Século XIX: Nacionalismo e Imperialismo",
        # Categorias difíceis de categorizar
        "Escravidão": "dropar",
        # Categorias-pai muito genéricas
        "Idade Antiga": "dropar",
        "Idade Moderna": "dropar",
        "Idade Contemporânea": "dropar",
        "Antiguidade Clássica": "dropar",
        "Economia": "dropar",
        "Idade Moderna (Vest SP)": "dropar",
        "Idade Moderna I": "dropar",
        "Idade Moderna II": "dropar",
        "Idade Moderna III": "dropar",
        "Idade Moderna IV": "dropar",
        "Idade Moderna V": "dropar",
        "Idade Moderna VI": "dropar",
        "Idade Moderna VII": "dropar",
        "Idade Contemporânea I": "dropar",
        "Idade Contemporânea II": "dropar",
        "Idade Contemporânea III": "dropar",
        "Idade Contemporânea IV": "dropar",
        "Idade Contemporânea V": "dropar",
        "Idade Contemporânea VI": "dropar",
        "Idade Contemporânea VII": "dropar",
        "Idade Contemporânea I (Vest SP)": "dropar",
        "Idade Contemporânea II (Vest SP)": "dropar",
        "Druidas": "dropar",
        "Guerra dos Sete Anos": "dropar",
        "Liberalismo": "dropar",
        "Revolução Meiji": "dropar",
    },
    "fisica": {
        "Aceleração da gravidade": "Gravitação",
        "Acústica": "Ondulatória",
        "Associação de Resistores": "Eletricidade",
        "Calorimetria": "Termologia",
        "Campo Elétrico": "Eletricidade",
        "Campo Magnético": "Eletromagnetismo",
        "Campo Magnético das Correntes": "Eletromagnetismo",
        "Capacitores": "Eletricidade",
        "Capacitores num circuito elétrico": "Eletricidade",
        "Carga Elétrica": "Eletricidade",
        "Cinemática": "Cinemática",
        "Cinemática I": "Cinemática",
        "Cinemática II": "Cinemática",
        "Cinemática III": "Cinemática",
        "Cinemática IV": "Cinemática",
        "Cinemática escalar da partícula": "Cinemática",
        "Comprimento de Onda de Broglie": "Física Moderna",
        "Constante de Planck": "Física Moderna",
        "Corrente Elétrica": "Eletricidade",
        "Deslocamento Escalar": "Cinemática",
        "Difração": "Ondulatória",
        "Dilatação Linear": "Termologia",
        "Dilatação Superficial": "Termologia",
        "Dilatação Volumétrica": "Termologia",
        "Dilatação dos Líquidos": "Termologia",
        "Dinâmica": "Dinâmica",
        "Dinâmica I": "Dinâmica",
        "Dinâmica II": "Dinâmica",
        "Dinâmica III": "Dinâmica",
        "Dinâmica IV": "Dinâmica",
        "Dioptro Plano": "Óptica",
        "Dualidade Onda-partícula": "Física Moderna",
        "Efeito Doppler": "Ondulatória",
        "Efeito Fotoelétrico": "Física Moderna",
        "Eletricidade I": "Eletricidade",
        "Eletricidade II": "Eletricidade",
        "Eletricidade III": "Eletricidade",
        "Eletricidade IV": "Eletricidade",
        "Eletrodinâmica": "Eletricidade",
        "Eletromagnetismo": "Eletromagnetismo",
        "Eletrostática": "Eletricidade",
        "Energia Cinética": "Dinâmica",
        "Energia Potencial Gravitacional e Elástica": "Dinâmica",
        "Energia e Trabalho": "Dinâmica",
        "Equação de Torricelli": "Cinemática",
        "Equilíbrio do Ponto Material": "Estática",
        "Equilíbrio dos Corpos Extensos": "Estática",
        "Escalas Termométricas": "Termologia",
        "Espelho plano": "Óptica",
        "Espelhos Esférico": "Óptica",
        "Estudo dos Gases": "Gases",
        "Estática": "Estática",
        "Estática I": "Estática",
        "Força Elástica": "Dinâmica",
        "Força Magnética": "Eletromagnetismo",
        "Força no MHS": "Cinemática",
        "Função Horária ou do Tempo no MHS": "Cinemática",
        "Física Moderna": "Física Moderna",
        "Gases": "Gases",
        "Gases: Equação Geral": "Gases",
        "Gases: Equação de Clapeyron": "Gases",
        "Gases: Gráficos de Transformações": "Gases",
        "Gases: Propriedades": "Gases",
        "Geradores - Força Eletromotriz": "Eletricidade",
        "Gravitação": "Gravitação",
        "Hidrostática": "Hidrostática",
        "Hipermetropia": "Óptica",
        "Hipermetropia e Miopia": "Óptica",
        "Impulso e Quantidade de Movimento": "Dinâmica",
        "Impulso e quantidade de movimento": "Dinâmica",
        "Indução Eletromagnética": "Eletromagnetismo",
        "Instrumentos Ópticos": "Óptica",
        "Introdução ao Magnetismo": "Eletromagnetismo",
        "Lançamento horizontal e oblíquo": "Cinemática",
        "Lei da Gravitação": "Gravitação",
        "Lei de Coulumb": "Eletricidade",
        "Lei de Ohm": "Eletricidade",
        "Leis de Kepler": "Gravitação",
        "Lentes Esféricas": "Óptica",
        "Lentes Esféricas: Lentes Convergentes": "Óptica",
        "Lentes Esféricas: Lentes Divergentes": "Óptica",
        "Lâminas de Faces Paralelas": "Óptica",
        "Magnetismo": "Eletromagnetismo",
        "Massa Mola no MHS": "Cinemática",
        "Miopia": "Óptica",
        "Momento ou Toque de uma Força": "Estática",
        "Movimento Harmônico Simples": "Cinemática",
        "Movimento Ondulatórios": "Ondulatória",
        "Movimento Uniforme": "Cinemática",
        "Movimento uniformemente Variado": "Cinemática",
        "Máquinas térmicas e Ciclo de Carnot": "Termodinâmica",
        "Notação Científica e Ordem de Grandeza": "Grandezas e Unidades",
        "Noções de Física Moderna": "Física Moderna",
        "Ondas Eletromagnéticas": "Ondulatória",
        "Ondas Estacionárias": "Ondulatória",
        "Ondas Sonoras": "Ondulatória",
        "Ondulatória I": "Ondulatória",
        "Ondulatória II": "Ondulatória",
        "Ondulatória III": "Ondulatória",
        "Ondulatória IV": "Ondulatória",
        "Período no MHS": "Cinemática",
        "Potência Elétrica": "Eletricidade",
        "Presbiopia": "Óptica",
        "Pressão": "Hidrostática",
        "Pressão Hidrostática": "Hidrostática",
        "Primeira Lei da Termodinâmica": "Termodinâmica",
        "Primeira Lei de Kepler": "Gravitação",
        "Princípio de Arquimedes - Empuxo": "Hidrostática",
        "Princípio de Huygens": "Ondulatória",
        "Prismas Óptico": "Óptica",
        "Propriedades dos Ímãs": "Eletromagnetismo",
        "Qualidade do Som": "Ondulatória",
        "Queda Livre": "Cinemática",
        "Reflexão da Luz": "Óptica",
        "Refração da Luz": "Óptica",
        "Satélites Artificiais ou Geoestacionário": "Gravitação",
        "Segunda Lei de Kepler": "Gravitação",
        "Sistema Internacional de Unidades": "Grandezas e Unidades",
        "Temperatura e Calor": "Termologia",
        "Temperatura e Dilatação": "Termologia",
        "Teorema de Pascal": "Hidrostática",
        "Teoria da Relatividade": "Física Moderna",
        "Teoria da Relatividade Restrita": "Física Moderna",
        "Terceira Lei de Kepler": "Gravitação",
        "Termodinâmica": "Termodinâmica",
        "Termologia": "Termologia",
        "Termologia II": "Termologia",
        "Termologia III": "Termologia",
        "Termologia IV": "Termologia",
        "Termologia V": "Termologia",
        "Termologia VI": "Termologia",
        "Trabalho de uma Força": "Dinâmica",
        "Trabalho e Energia": "Dinâmica",
        "Velocidade Média": "Cinemática",
        "Vetor": "Vetores",
        "Volume e Densidade": "Hidrostática",
        "Óptica": "Óptica",
        "Óptica Geométrica": "Óptica",
        "Óptica da Visão": "Óptica",
    },
    "quimica": {
        ">Cinética": "Físico-Química",
        ">Cinética II": "Físico-Química",
        ">Cinética: Lei da Velocidade das Reações": "Físico-Química",
        ">Fatores que Influenciam a Velocidade das Reações": "Físico-Química",
        ">Velocidade das Reações Cinéticas": "Físico-Química",
        "Aldeído e Cetonas": "Química Orgânica",
        "Aldeídos": "Química Orgânica",
        "Atomística": "Estrutura Atômica",
        "Atomística (EsPCEx)": "Estrutura Atômica",
        "Atomística (ITA)": "Estrutura Atômica",
        "Balanceamento por oxirredução": "Eletroquímica",
        "Bases ou Hidróxidos": "Química Inorgânica",
        "Bateria ou Pilha de Lítio-iodo": "Eletroquímica",
        "Baterias ou Pilhas Recarregáveis": "Eletroquímica",
        "Biodiesel": "Meio Ambiente",
        "Biomoléculas": "Química Orgânica",
        "Camada de Ozônio": "Meio Ambiente",
        "Cetonas": "Química Orgânica",
        "Chernobyl": "Radioatividade",
        "Chuva Ácida": "Meio Ambiente",
        "Cinética Química": "Físico-Química",
        "Classif. das cadeias carbônicas": "Química Orgânica",
        "Classificação das Cadeias Carbônicas": "Química Orgânica",
        "Combustíveis Fósseis": "Meio Ambiente",
        "Compostos Aromáticos": "Química Orgânica",
        "Concentração comum e Densidade": "Físico-Química",
        "Concentração em quantidade de matéria/L ou mol/L": "Físico-Química",
        "Constante de Equilíbrio (Kc)": "Físico-Química",
        "Constante de Equilíbrio (Relação entre Kp e Kc)": "Físico-Química",
        "Constante de Hidrólise": "Físico-Química",
        "Constante de Ionização": "Físico-Química",
        "Curva do Aquecimento": "Química Geral",
        "Cálculo Estequiométrico (EsPCEx)": "Estequiometria e Cálculos",
        "Cálculo Estequiométrico (ITA)": "Estequiometria e Cálculos",
        "Densidade dos Gases": "Gases",
        "Desenvolvimento Sustentável/Sustentabilidade": "Meio Ambiente",
        "Deslocamento de Equilíbrio: Princípio de Le Chatelier": "Físico-Química",
        "Dessalinização da Água": "Meio Ambiente",
        "Difusão e Efusão Gasosa": "Gases",
        "Diluição de Soluções:": "Físico-Química",
        "Distribuição Eletrônica I": "Estrutura Atômica",
        "Distribuição Eletrônica II": "Estrutura Atômica",
        "Elementos Químicos": "Estrutura Atômica",
        "Eletrólise": "Eletroquímica",
        "Eletrólise aquosa": "Eletroquímica",
        "Eletrólise: Eletrólise Ígnea": "Eletroquímica",
        "Eletrólise: Estequiometria": "Estequiometria e Cálculos",
        "Energia Nuclear": "Radioatividade",
        "Entalpia (calor) de Formação e Combustão": "Físico-Química",
        "Equação do Gás Ideal (Equação de Clapeyron)": "Gases",
        "Equação ou Lei Geral dos Gases": "Gases",
        "Equilíbrio Iônico": "Físico-Química",
        "Equilíbrio Químico": "Físico-Química",
        "Equilíbrio químico": "Físico-Química",
        "Espontaneidade das Reações": "Físico-Química",
        "Estequiometria": "Estequiometria e Cálculos",
        "Estequiometria das Reações Químicas": "Estequiometria e Cálculos",
        "Estrutura atômica da matéria": "Estrutura Atômica",
        "Estudo dos gases (ITA)": "Gases",
        "Excesso e Limitante (EsPCEx)": "Estequiometria e Cálculos",
        "Fukushima": "Radioatividade",
        "Funções Inorgânicas": "Química Inorgânica",
        "Funções Nitrogenadas": "Química Orgânica",
        "Funções Orgânicas": "Química Orgânica",
        "Funções e Reações Inorgânicas": "Química Inorgânica",
        "Física-química": "Físico-Química",
        "Físico-química I": "Físico-Química",
        "Físico-química II": "Físico-Química",
        "Físico-química III": "Físico-Química",
        "Físico-química IV": "Físico-Química",
        "Fórmulas Químicas": "Química Geral",
        "Galvanostegia e Galvanoplastia": "Eletroquímica",
        "Gases e Estequiometria": "Estequiometria e Cálculos",
        "Geometria Molecular II": "Ligações Químicas",
        "Gás Metano": "Gases",
        "Haletos Orgânicos": "Química Orgânica",
        "Hibridização ou Hibridação do Carbono": "Ligações Químicas",
        "Hidrocarbonetos": "Química Orgânica",
        "Hidrólise Salina": "Físico-Química",
        "Hidróxido de Potássio": "Química Inorgânica",
        "Introdução ao Equilíbrio Químico": "Físico-Química",
        "Introdução à Química Orgânica": "Química Orgânica",
        "Isomeria": "Química Orgânica",
        "Lei da diluição de Ostwald": "Físico-Química",
        "Lei de Hess": "Físico-Química",
        "Ligações Químicas": "Ligações Químicas",
        "Ligações Químicas (EsPCEx)": "Ligações Químicas",
        "Ligações Sigma e Pi": "Ligações Químicas",
        "Ligações químicas e interações intermoleculares": "Ligações Químicas",
        "Liofilização": "Química Geral",
        "Lixo Atômico": "Radioatividade",
        "Mistura Gasosa": "Química Geral",
        "Mistura de Soluções: Sem com reação química": "Físico-Química",
        "Mistura de soluções: Com sem reação química": "Físico-Química",
        "Modelos Atômicos": "Estrutura Atômica",
        "Modelos Atômicos de Rutherford-Bohr": "Estrutura Atômica",
        "Mol e Massa Molar": "Estequiometria e Cálculos",
        "Mol e Número de Avogadro": "Estequiometria e Cálculos",
        "Mudanças De Estado Físico": "Química Geral",
        "Nomenclatura de Hidrocarbonetos": "Química Orgânica",
        "Nox - Número de Oxidação": "Eletroquímica",
        "Os coeficientes e as Quantidades de Substância (mol)": "Estequiometria e Cálculos",
        "Oxidação e redução": "Eletroquímica",
        "Oxirreducão na Obtenção de Substâncias Simples": "Eletroquímica",
        "Partes por milhão (ppm)": "Físico-Química",
        "Petróleo": "Meio Ambiente",
        "Pilha seca de Leclanché ou Pilha Ácida": "Eletroquímica",
        "Pilhas": "Eletroquímica",
        "Pilhas Alcalinas": "Eletroquímica",
        "Polaridade": "Ligações Químicas",
        "Poluição Ambiental": "Meio Ambiente",
        "Potencial das Pilhas": "Físico-Química",
        "Potencial de Redução": "Físico-Química",
        "Principais Funções dos Hidrocarbonetos": "Química Orgânica",
        "Produto de Solubilidade": "Físico-Química",
        "Propriedade da Matéria e Sistemas": "Química Geral",
        "Propriedades Físicas": "Química Geral",
        "Propriedades Físico-químicas": "Química Geral",
        "Propriedades da Matéria (EsPCEx)": "Química Geral",
        "Propriedades da Matéria (ITA)": "Química Geral",
        "Propriedades da matéria": "Química Geral",
        "Propriedades dos Compostos Orgânicos": "Química Geral",
        "Pureza do Reagente e Rendimento": "Estequiometria e Cálculos",
        "Pureza e Rendimento (EsPCEx)": "Estequiometria e Cálculos",
        "Quantidades, medidas e análises elementar": "Estequiometria e Cálculos",
        "Química Ambiental I": "Meio Ambiente",
        "Química Inorgânica I": "Química Inorgânica",
        "Química Inorgânica III": "Química Inorgânica",
        "Química Inorgânica IV": "Química Inorgânica",
        "Química Orgânica": "Química Orgânica",
        "Química Orgânica I": "Química Orgânica",
        "Química Orgânica II": "Química Orgânica",
        "Química Orgânica III": "Química Orgânica",
        "Química Orgânica IV": "Química Orgânica",
        "Radioatividade": "Radioatividade",
        "Radioatividade: Fissão e Fusão Nuclear": "Radioatividade",
        "Radioatividade: Meia-Vida": "Radioatividade",
        "Raios: Alfa, Beta e Gama": "Radioatividade",
        "Reagente em Excesso e Reagente Limitante": "Estequiometria e Cálculos",
        "Reação de Substituição nos Aromáticos": "Química Orgânica",
        "Reações Inorgânicas": "Química Inorgânica",
        "Reações Orgânicas": "Química Orgânica",
        "Reações Orgânicas de Adição": "Química Orgânica",
        "Reações Orgânicas de Substituição": "Química Orgânica",
        "Relações entre concentração comum, molar, título e densidade": "Físico-Química",
        "Rendimento de uma Reação Química": "Estequiometria e Cálculos",
        "Sabões e Detergentes": "Química Orgânica",
        "Semelhanças Atômicas": "Estrutura Atômica",
        "Separação de Misturas Químicas": "Química Geral",
        "Separação de misturas": "Química Geral",
        "Solução Tampão": "Físico-Química",
        "Soluções": "Físico-Química",
        "Soluções:": "Físico-Química",
        "Substância Pura e Mistura": "Química Geral",
        "Tabela Periódica (EsPCEx)": "Tabela Periódica",
        "Tabela periódica": "Tabela Periódica",
        "Teoria Ácido-Base": "Química Inorgânica",
        "Termoquímica": "Físico-Química",
        "Termoquímica (Introdução)": "Físico-Química",
        "Transformações Gasosas": "Química Geral",
        "Transformações da Matéria": "Química Geral",
        "Tratamento da Água": "Meio Ambiente",
        "Volume Molar dos Gases": "Estequiometria e Cálculos",
        "pH": "Físico-Química",
        "pH e pOH": "Físico-Química",
        "Ácidos e Bases": "Química Inorgânica",
        "Ácidos e Bases de Substâncias Orgânicas": "Química Inorgânica",
        "Álcool, Fenol e Enol": "Química Orgânica",
        "Átomos e Íons": "Estrutura Atômica",
        "Éteres e Ésteres": "Química Orgânica",
        "Eletroquímica": "Eletroquímica",
        "Fórmulas estruturais": "Química Orgânica",
        ">Teoria das Colisões": "Físico-Química",
        ">Condições Para a Ocorrência de Reações Químicas": "Físico-Química",
        "Solubilidade": "Físico-Química",
        "Densidade e Massa Específica": "Química Geral",
        "Química Geral I": "Química Geral",
        "Química Geral II": "Química Geral",
        "Química Geral III": "Química Geral",
        "Química Geral IV": "Química Geral",
        "Química Inorgânicas (EsPCEx)": "Química Inorgânica",
        "Polímeros": "Química Orgânica",
        "Ponto de Fusão e Ebulição": "Físico-Química",
        "Fração": "Química Geral",
    },
    "biologia": {
        "A História dos Seres Vivos": "Evolução",
        "Acondroplasia ou Nanismo": "Doenças Genéticas e Síndromes",
        "Acromatopsia": "Doenças Genéticas e Síndromes",
        "Agamaglobulinemia": "Doenças Genéticas e Síndromes",
        "Albinismo": "Doenças Genéticas e Síndromes",
        "Alcoolismo": "Saúde Pública",
        "Alelos múltiplos ou polialelia": "Genética",
        "Algas": "Protistas",
        "Alterações cromossômicas": "Genética",
        "Amazônia": "Ecologia",
        "Anatomia/Fisiologia": "Fisiologia",
        "Anelídeos": "Zoologia",
        "Anemia Falciforme": "Doenças Genéticas e Síndromes",
        "Anexos Embrionários": "Embriologia",
        "Anfíbios": "Zoologia",
        "Aquecimento Global": "Ecologia",
        "Artrópodes": "Zoologia",
        "Aterosclerose": "Fisiologia",
        "Aves": "Zoologia",
        "Bacteriófago": "Virologia",
        "Bioquímica": "Bioquímica",
        "Bioquímica I": "Bioquímica",
        "Biotecnologia": "Biotecnologia",
        "Biotecnologia I": "Biotecnologia",
        "Biotecnologia II": "Biotecnologia",
        "Botulismo": "Bacterioses",
        "Botânica": "Botânica",
        "Botânica (Vest SP)": "Botânica",
        "Botânica I": "Botânica",
        "Botânica II": "Botânica",
        "Botânica III": "Botânica",
        "Botânica IV": "Botânica",
        "Botânica V": "Botânica",
        "Botânica VI": "Botânica",
        "Botânica VII": "Botânica",
        "Botânica VIII": "Botânica",
        "Briófitas e pteridófitas": "Botânica",
        "CRISPR - Edição Genética ou Terapia Gênica": "Genética",
        "Caatinga": "Ecologia",
        "Cadeias e teias alimentares": "Ecologia",
        "Características gerais dos animais": "Zoologia",
        "Catapora": "Viroses",
        "Cerrado": "Ecologia",
        "Ciclos biogeoquimicos": "Ecologia",
        "Citologia I": "Citologia",
        "Citologia II": "Citologia",
        "Citologia III": "Citologia",
        "Citologia IV": "Citologia",
        "Citologia V": "Citologia",
        "Citologia VI": "Citologia",
        "Citologia VII": "Citologia",
        "Citologia VIII": "Citologia",
        "Citoplasma": "Citologia",
        "Citoplasma e Organelas": "Citologia",
        "Clonagem, PCT e Terapia Gênica": "Genética",
        "Cordados: Cefalocordados e Urocordados": "Zoologia",
        "Coronavírus": "Virologia",
        "Crise na Vacinação": "Saúde Pública",
        "Células Tronco": "Biotecnologia",
        "Cólera": "Bacterioses",
        "Daltonismo": "Doenças Genéticas e Síndromes",
        "Darwinismo e Lamarckismo": "Evolução",
        "Dengue, Chikungunya e Zika": "Viroses",
        "Desenvolvimento Embrionário de Animais": "Embriologia",
        "Determinação do Sexo": "Genética",
        "Distrofia Muscular de Duchenne": "Doenças Genéticas e Síndromes",
        "Divisão Celular: Meiose": "Citologia",
        "Divisão Celular: Mitose": "Citologia",
        "Divisão celular": "Citologia",
        "Doença de Chagas": "Protozooses",
        "Ecologia": "Ecologia",
        "Ecologia (Vest SP)": "Ecologia",
        "Ecologia I": "Ecologia",
        "Ecologia II": "Ecologia",
        "Ecologia III": "Ecologia",
        "Ecologia IV": "Ecologia",
        "Ecologia V": "Ecologia",
        "Ecologia VI": "Ecologia",
        "Ecologia VII": "Ecologia",
        "Ecologia VIII": "Ecologia",
        "Ecossistemas": "Ecologia",
        "Embriogênes, Células-ovo ou Zigoto": "Embriologia",
        "Embriologia": "Embriologia",
        "Embriologia I": "Embriologia",
        "Embriologia II": "Embriologia",
        "Embriologia III": "Embriologia",
        "Embriologia IV": "Embriologia",
        "Embriologia V": "Embriologia",
        "Enzimas": "Bioquímica",
        "Equinodermos": "Zoologia",
        "Especialização da Membrana": "Citologia",
        "Espécies Invasoras": "Ecologia",
        "Esquistossomose": "Protozooses",
        "Estrutura da Membrana": "Citologia",
        "Estrutura dos Vírus": "Virologia",
        "Eutrofização": "Ecologia",
        "Evolução": "Evolução",
        "Evolução Humana": "Evolução",
        "Evolução e classificação das plantas": "Evolução",
        "Fator RH": "Genética",
        "Febre Amarela": "Viroses",
        "Fermentação": "Fisiologia",
        "Fibrose cística": "Doenças Genéticas e Síndromes",
        "Fisiologia Animal": "Fisiologia",
        "Fisiologia Humana": "Fisiologia",
        "Fisiologia I": "Fisiologia",
        "Fisiologia II": "Fisiologia",
        "Fisiologia III": "Fisiologia",
        "Fisiologia IV": "Fisiologia",
        "Fisiologia V": "Fisiologia",
        "Fisiologia VI": "Fisiologia",
        "Fisiologia Vegetal": "Fisiologia",
        "Fisiologia das angiospermas": "Fisiologia",
        "Folhetos Embrionários": "Embriologia",
        "Formação de Novas Espécies": "Evolução",
        "Fotossíntese": "Botânica",
        "Fotossíntese e quimiossíntese": "Botânica",
        "Fungos": "Fungos",
        "Gastrulação": "Embriologia",
        "Genética": "Genética",
        "Genética I": "Genética",
        "Genética II": "Genética",
        "Genética III": "Genética",
        "Genética IV": "Genética",
        "Genética V": "Genética",
        "Genética VI": "Genética",
        "Genética VII": "Genética",
        "Genética VIII": "Genética",
        "Gimnospermas e angiospermas": "Botânica",
        "Glicídios ou Carboidratos": "Bioquímica",
        "Gripe": "Viroses",
        "Gripe Aviária ou Gripe do Frango": "Viroses",
        "Gripe Suína, H1N1 ou Gripe A": "Viroses",
        "HIV/Aids": "Viroses",
        "HPV": "Viroses",
        "Hemofilia": "Doenças Genéticas e Síndromes",
        "Herança Ligada Ao Sexo": "Genética",
        "Heredograma": "Genética",
        "Herpes": "Viroses",
        "Hipertensão Arterial": "Saúde Pública",
        "Histologia": "Histologia",
        "Histologia I": "Histologia",
        "Histologia II": "Histologia",
        "Histologia III": "Histologia",
        "Histologia IV": "Histologia",
        "Histologia V": "Histologia",
        "Histologia VI": "Histologia",
        "Histologia VII": "Histologia",
        "Histologia VIII": "Histologia",
        "Histologia e morfologia das angiospermas": "Botânica",
        "Hormônios Vegetais ou Fitormônios": "Fisiologia",
        "Hábitat e Nicho Ecológico": "Ecologia",
        "Imunologia": "Imunologia",
        "Incontinência Pigmentar ou Síndrome de BlockSulzberger": "Doenças Genéticas e Síndromes",
        "Informação Genética": "Genética",
        "Intolerância à Lactose": "Saúde Pública",
        "Klebsiella pneumoniae carbapenamase (KPC)": "Bacterioses",
        "Leishmaniose": "Protozooses",
        "Leptospirose": "Protozooses",
        "Lipomatose Simétrica Benigna": "Doenças Genéticas e Síndromes",
        "Lipídios": "Bioquímica",
        "Líquens": "Botânica",
        "Mal de Alzheimer": "Doenças Genéticas e Síndromes",
        "Malária": "Protozooses",
        "Mamíferos": "Zoologia",
        "Mata Atlântica": "Ecologia",
        "Membrana Plasmática": "Citologia",
        # muito genérico
        "Microbiologia": "dropar",
        "Moluscos": "Zoologia",
        "Musgos": "Botânica",
        "Mutações Cromossômicas": "Genética",
        "Mutações Genéticas": "Genética",
        "Mutações e Seleção Natural": "Evolução",
        "Mórula e Blástula": "Embriologia",
        "Nomenclatura": "Taxonomia",
        "Nêurula": "Embriologia",
        "Níveis de Organização": "Ecologia",
        "Núcleo Celular": "Citologia",
        "Núcleo, cromossomos e clonagem": "Citologia",
        "Organogênese": "Embriologia",
        "Osmose": "Citologia",
        "Parkinson": "Doenças Genéticas e Síndromes",
        "Partes da Planta": "Botânica",
        "Peixes": "Zoologia",
        "Peste Bubônica ou Peste Negra": "Bacterioses",
        "Plantas Epífitas": "Botânica",
        "Platelmintos e Nematódeos": "Zoologia",
        "Pneumonia": "Bacterioses",
        "Poliomielite": "Viroses",
        "Poluição": "Ecologia",
        "Poríferos e Cnidários": "Zoologia",
        "Primeira lei de mendel": "Genética",
        "Probabilidade Genética": "Genética",
        "Procariontes": "Procariontes",
        "Programas de saúde I": "Saúde Pública",
        "Programas de saúde II": "Saúde Pública",
        "Proteína": "Bioquímica",
        "Proteínas": "Bioquímica",
        "Protozoários I": "Protistas",
        "Protozoários II": "Protistas",
        "Raiva": "Viroses",
        "Reino Animal": "Zoologia",
        "Reino Animalia": "Zoologia",
        "Reino Fungi": "Fungos",
        "Reino Monera": "Procariontes",
        "Reino Protista": "Protistas",
        "Relações Ecológicas": "Ecologia",
        "Reprodução Humana": "Reprodução Humana",
        "Reprodução e desenvolvimento": "Reprodução Humana",
        "Respiração celular e fermetação": "Fisiologia",
        "Retrovírus": "Virologia",
        "Rubéola": "Viroses",
        "Répteis": "Zoologia",
        "Sangue, linfa e Sistema Imunitário": "Fisiologia",
        "Segmentação": "Embriologia",
        "Segunda lei de Mendel": "Genética",
        "Sistema Endócrino": "Fisiologia",
        "Sistema Excretor": "Fisiologia",
        "Sistema Locomotor": "Fisiologia",
        "Sistema Nervoso": "Fisiologia",
        "Sistema Respiratório": "Fisiologia",
        "Sistema Sensorial": "Fisiologia",
        "Sistema circulatório": "Fisiologia",
        "Sistema digestório e Nutrição": "Fisiologia",
        "Sistema sanguíneo ABO": "Genética",
        "Sucessão ecológica": "Ecologia",
        "Superbactérias": "Procariontes",
        "Síndrome Antissintetase (SAS)": "Doenças Genéticas e Síndromes",
        "Síndrome Edematos": "Doenças Genéticas e Síndromes",
        "Síndrome MELAS": "Doenças Genéticas e Síndromes",
        "Síndrome Metabólica": "Doenças Genéticas e Síndromes",
        "Síndrome Respiratória Aguda Grave (SRAG)": "Doenças Genéticas e Síndromes",
        "Síndrome Spoan": "Doenças Genéticas e Síndromes",
        "Síndrome da Rubéola congênita": "Doenças Genéticas e Síndromes",
        "Síndrome de Berardinelli-Seip": "Doenças Genéticas e Síndromes",
        "Síndrome de Bloom": "Doenças Genéticas e Síndromes",
        "Síndrome de Conn": "Doenças Genéticas e Síndromes",
        "Síndrome de Down": "Doenças Genéticas e Síndromes",
        "Síndrome de Edwards": "Doenças Genéticas e Síndromes",
        "Síndrome de Frey": "Doenças Genéticas e Síndromes",
        "Síndrome de Gaucher": "Doenças Genéticas e Síndromes",
        "Síndrome de Guillain": "Doenças Genéticas e Síndromes",
        "Síndrome de Kartagener": "Doenças Genéticas e Síndromes",
        "Síndrome de Klinefelter": "Doenças Genéticas e Síndromes",
        "Síndrome de Leigh": "Doenças Genéticas e Síndromes",
        "Síndrome de Lorenzo - Adrenoleucodistrofia (ADL)": "Doenças Genéticas e Síndromes",
        "Síndrome de Marfan": "Doenças Genéticas e Síndromes",
        "Síndrome de Morris": "Doenças Genéticas e Síndromes",
        "Síndrome de Nance-Horan": "Doenças Genéticas e Síndromes",
        "Síndrome de Noonan": "Doenças Genéticas e Síndromes",
        "Síndrome de Ondine": "Doenças Genéticas e Síndromes",
        "Síndrome de Patau": "Doenças Genéticas e Síndromes",
        "Síndrome de Turner": "Doenças Genéticas e Síndromes",
        "Síndrome de Wolf-Hirschhorn": "Doenças Genéticas e Síndromes",
        "Síndrome de Zellweger ou Síndrome Cerebrohepatorenal": "Doenças Genéticas e Síndromes",
        "Síndrome do Cri-du-Chat": "Doenças Genéticas e Síndromes",
        "Síndrome dos Vômitos Cíclicos (SVC)": "Doenças Genéticas e Síndromes",
        "Síndromes de câncer hereditário": "Doenças Genéticas e Síndromes",
        "Taxonomia": "Taxonomia",
        "Tecido Conjuntivo Ósseo e Cartilaginoso": "Histologia",
        "Tecido Epitelial": "Histologia",
        "Tecido Epitelial Glandular": "Histologia",
        "Tecido Epitelial de Revestimento": "Histologia",
        "Tecido Muscular": "Histologia",
        "Tecido Nervoso": "Histologia",
        "Tecido Sanguíneo e Linfático": "Histologia",
        "Tecidos Conjuntivos": "Histologia",
        "Teoria Sintética da Evolução": "Evolução",
        "Teste de DNA e Paternidade ou Fingerprinting": "Genética",
        "Toxoplasmose": "Protozooses",
        "Transgênicos": "Genética",
        "Transporte Através da Membrana": "Citologia",
        "Tuberculose": "Bacterioses",
        "Varíola": "Viroses",
        "Vasos Condutores": "Botânica",
        "Visão geral da célula": "Citologia",
        "Vitamina A (Retinol)": "Bioquímica",
        "Vitamina C (Ácido Ascórbico)": "Bioquímica",
        "Vitamina Complexo B": "Bioquímica",
        "Vitamina D (Calciferol)": "Bioquímica",
        "Vitaminas": "Bioquímica",
        "Vírus": "Virologia",
        "Zoologia I": "Zoologia",
        "Zoologia II": "Zoologia",
        "Zoologia III": "Zoologia",
        "Zoologia IV": "Zoologia",
        "Zoologia V": "Zoologia",
        "Zoologia VI": "Zoologia",
        "Zoologia VII": "Zoologia",
        "Zoologia VIII": "Zoologia",
        "Ácido Nucleico": "Bioquímica",
        "Ácidos nucleicos": "Bioquímica",
        "Água": "Bioquímica",
        "Água e Sais Minerais": "Bioquímica",
        "Água e os Sais Minerais": "Bioquímica",
    },
    "matematica": {
        "Geometria Plana I": "Geometria Plana",
        "Geometria Plana II": "Geometria Plana",
        "Geometria Plana III": "Geometria Plana",
        "Geometria Plana": "Geometria Plana",
        "Polígonos": "Geometria Plana",
        "Poligonos": "Geometria Plana",
        "Polígonos Regulares": "Geometria Plana",
        "Triângulos": "Geometria Plana",
        "Triângulo": "Geometria Plana",
        "Triângulo Retângulo": "Geometria Plana",
        "Semelhança de Triângulos": "Geometria Plana",
        "Trapézio": "Geometria Plana",
        "Trapézios": "Geometria Plana",
        "Retângulo": "Geometria Plana",
        "Retângulos": "Geometria Plana",
        "Quadriláteros": "Geometria Plana",
        "Losango": "Geometria Plana",
        "Paralelogramo": "Geometria Plana",
        "Ângulos": "Geometria Plana",
        "Áreas e Perímetros": "Geometria Plana",
        "Círculos e Circunferência": "Geometria Plana",
        "Circunferência": "Geometria Plana",
        "Círculo e Circunferência": "Geometria Plana",
        "Lei dos Senos e Cossenos": "Geometria Plana",
        "Geometria Plana: Triângulos": "Geometria Plana",
        "Estatística: I": "Estatística e Interpretação de Gráficos",
        "Estatística: II": "Estatística e Interpretação de Gráficos",
        "Estatística: III": "Estatística e Interpretação de Gráficos",
        "Estatística: VI": "Estatística e Interpretação de Gráficos",
        "Estatística": "Estatística e Interpretação de Gráficos",
        "Média Aritmética": "Estatística e Interpretação de Gráficos",
        "Média Ponderada": "Estatística e Interpretação de Gráficos",
        "Inter. de Gráficos I": "Estatística e Interpretação de Gráficos",
        "Aritmética: I": "Aritmética e Matemática Básica",
        "Aritmética: II": "Aritmética e Matemática Básica",
        "Aritmética: III": "Aritmética e Matemática Básica",
        "Aritmética: IV": "Aritmética e Matemática Básica",
        "Números Primos e Compostos": "Aritmética e Matemática Básica",
        "Números Decimais": "Aritmética e Matemática Básica",
        "Frações": "Aritmética e Matemática Básica",
        "Fração": "Aritmética e Matemática Básica",
        "Potenciação": "Aritmética e Matemática Básica",
        "Radiciação": "Aritmética e Matemática Básica",
        "Multiplos e Divisores": "Aritmética e Matemática Básica",
        "MDC e MMC": "Aritmética e Matemática Básica",
        "MMC/MDC": "Aritmética e Matemática Básica",
        "Expressões Numérica": "Aritmética e Matemática Básica",
        "Sistema Métrico": "Aritmética e Matemática Básica",
        "Sistema Métrico e de Numeração": "Aritmética e Matemática Básica",
        "Conjuntos Numéricos I": "Aritmética e Matemática Básica",
        "Conjuntos Numéricos II": "Aritmética e Matemática Básica",
        "Conjuntos": "Aritmética e Matemática Básica",
        "Teoria dos Conjuntos": "Aritmética e Matemática Básica",
        "Matemática Básica": "Aritmética e Matemática Básica",
        "Equações do Primeiro Grau": "Álgebra e Equações",
        "Equações do segundo grau": "Álgebra e Equações",
        "Equações Irracionais e Biquadradas": "Álgebra e Equações",
        "Equações Polinomiais ou Algébricas": "Álgebra e Equações",
        "Equações do Terceiro Grau": "Álgebra e Equações",
        "Equações": "Álgebra e Equações",
        "Inequações": "Álgebra e Equações",
        "Inequação Polinomias ou do Primeiro Grau": "Álgebra e Equações",
        "Inequação do Segundo Grau": "Álgebra e Equações",
        "Sistema de Equações": "Álgebra e Equações",
        "Sistemas Lineares": "Álgebra e Equações",
        "Sistemas de Equações": "Álgebra e Equações",
        "Produtos Notáveis/Fatoração": "Álgebra e Equações",
        "Expressões Algébricas": "Álgebra e Equações",
        "Frações Algébricas": "Álgebra e Equações",
        "Polinômio": "Álgebra e Equações",
        "Relações de Girard": "Álgebra e Equações",
        "Funções: I": "Funções",
        "Funções: II": "Funções",
        "Funções: III": "Funções",
        "Funções: IV": "Funções",
        "Funções": "Funções",
        "Função Polinomial 1° grau": "Funções",
        "Função Quadrática ou do 2° grau": "Funções",
        "Função Modular": "Funções",
        "Função Exponencial": "Funções",
        "Função Logarítmica": "Funções",
        "Função Bijetora": "Funções",
        "Função Composta": "Funções",
        "Função Inversa": "Funções",
        "Sequência | PA e PG": "Progressões e Sequências",
        "Sequência: P.A": "Progressões e Sequências",
        "Sequência: P.G": "Progressões e Sequências",
        "Progressões": "Progressões e Sequências",
        "Sequências": "Progressões e Sequências",
        "Sequências Numéricas": "Progressões e Sequências",
        "Razão e Proporção I": "Razão, Proporção e Porcentagem",
        "Razão e Proporção II": "Razão, Proporção e Porcentagem",
        "Razão e Proporção III": "Razão, Proporção e Porcentagem",
        "Razão e Proporção IV": "Razão, Proporção e Porcentagem",
        "Razão e Proporção V": "Razão, Proporção e Porcentagem",
        "Razão e Proporção VI": "Razão, Proporção e Porcentagem",
        "Razão e Proporção VII": "Razão, Proporção e Porcentagem",
        "Escala": "Razão, Proporção e Porcentagem",
        "Razão e Proporção": "Razão, Proporção e Porcentagem",
        "Grandezas Proporcionais": "Razão, Proporção e Porcentagem",
        "Regra de Três": "Razão, Proporção e Porcentagem",
        "Porcentagem I": "Razão, Proporção e Porcentagem",
        "Porcentagem II": "Razão, Proporção e Porcentagem",
        "Porcentagem": "Razão, Proporção e Porcentagem",
        "Análise combinatória I": "Análise Combinatória e Probabilidade",
        "Análise combinatória II": "Análise Combinatória e Probabilidade",
        "Análise combinatória III": "Análise Combinatória e Probabilidade",
        "Análise combinatória": "Análise Combinatória e Probabilidade",
        "Análise Combinatória (Vest SP)": "Análise Combinatória e Probabilidade",
        "Combinação": "Análise Combinatória e Probabilidade",
        "Permutação": "Análise Combinatória e Probabilidade",
        "Binomio de Newton": "Análise Combinatória e Probabilidade",
        "Análise Combinatória e Probabilidade": "Análise Combinatória e Probabilidade",
        "Probabilidade": "Análise Combinatória e Probabilidade",
        "Probabilidade (Vest SP)": "Análise Combinatória e Probabilidade",
        "Juros Simples": "Matemática Financeira",
        "Juros Composto": "Matemática Financeira",
        "Matemática Financeira": "Matemática Financeira",
        "Matemática Financeira (Vest SP)": "Matemática Financeira",
        "Geometria Espacial": "Geometria Espacial e Sólidos",
        "Geometria Espacial II": "Geometria Espacial e Sólidos",
        "Cilindro": "Geometria Espacial e Sólidos",
        "Cilindros": "Geometria Espacial e Sólidos",
        "Cone": "Geometria Espacial e Sólidos",
        "Cones": "Geometria Espacial e Sólidos",
        "Esferas": "Geometria Espacial e Sólidos",
        "Cubos": "Geometria Espacial e Sólidos",
        "Prismas": "Geometria Espacial e Sólidos",
        "Pirâmides": "Geometria Espacial e Sólidos",
        "Paralelepípedo": "Geometria Espacial e Sólidos",
        "Paralelepípedos": "Geometria Espacial e Sólidos",
        "Poliedros": "Geometria Espacial e Sólidos",
        "Sólidos de Revolução": "Geometria Espacial e Sólidos",
        "Planificação de Sólidos": "Geometria Espacial e Sólidos",
        "Projeção Ortogonal": "Geometria Espacial e Sólidos",
        "Geometria Analítica": "Geometria Analítica",
        "Alinhamento de Três Pontos": "Geometria Analítica",
        "Circunferência e Reta": "Geometria Analítica",
        "Equação da reta": "Geometria Analítica",
        "Ponto Médio e Baricentro": "Geometria Analítica",
        "Distância Entre Dois Pontos": "Geometria Analítica",
        "Plano Cartesiano": "Geometria Analítica",
        "Vetores": "Geometria Analítica",
        "Geometria Analítica (Vest SP)": "Geometria Analítica",
        "Trigonometria": "Trigonometria",
        "Razões Trigonométricas": "Trigonometria",
        "Círculo Trigonométrico": "Trigonometria",
        "Equações Trigonométricas": "Trigonometria",
        "Funções Trigonométricas": "Trigonometria",
        "Operações com Arcos": "Trigonometria",
        "Números Complexos": "Números Complexos",
        "Números Complexos - Argand-Gauss": "Números Complexos",
        "Matrizes": "Álgebra Linear e Matrizes",
        "Matriz e Sistema Linear": "Álgebra Linear e Matrizes",
        "Determinantes": "Álgebra Linear e Matrizes",
        "Matrizes e Determinantes": "Álgebra Linear e Matrizes",
        "Matriz: Elementos Internos": "Álgebra Linear e Matrizes",
        "Matriz Inversa": "Álgebra Linear e Matrizes",
        "Matriz Ortogonal": "Álgebra Linear e Matrizes",
        "Matriz Transposta": "Álgebra Linear e Matrizes",
        "Equação Matricial": "Álgebra Linear e Matrizes",
        "Álgebra Linear": "Álgebra Linear e Matrizes",
        "Álgebra Linear (Vest SP)": "Álgebra Linear e Matrizes",
        "Logaritmos": "Logaritmos e Exponenciais",
        "Teorema de Pitágoras": "Geometria Plana",
        "Divisibilidade": "Aritmética e Matemática Básica",
        "Equação do Primeiro Grau": "Álgebra e Equações",
        "Inter. de Gráficos": "Estatística e Interpretação de Gráficos",
        "Análise Combinatória I": "Análise Combinatória e Probabilidade",
        "Análise Combinatória II": "Análise Combinatória e Probabilidade",
        "PFC": "Análise Combinatória e Probabilidade",
        "Princípio Fundamental da Contagem": "Análise Combinatória e Probabilidade",
        "Aritmética, 2018": "Aritmética e Matemática Básica",
        "Aritmética, Enem PPL 2019": "Aritmética e Matemática Básica",
        "Estatística e Análise de gráficos, Enem 2019": "Estatística e Interpretação de Gráficos",
        "Estatística, Enem PPL 2019": "Estatística e Interpretação de Gráficos",
        "Estatística, Enem 2018": "Estatística e Interpretação de Gráficos",
        "Funções, Enem 2019": "Funções",
        "Geometria, Enem 2019": "Geometria Plana",
        "Geometria, Enem PPL 2019": "Geometria Plana",
        "Geometria, Enem 2018": "Geometria Plana",
        "Geometria Analı́tica, Enem 2019": "Geometria Analítica",
        "Geometria Espacial, Enem 2019": "Geometria Espacial e Sólidos",
        "Logaritmo, Enem 2019": "Logaritmos e Exponenciais",
        "Logaritmo, Enem PPL 2019": "Logaritmos e Exponenciais",
        "Probabilidade, Enem 2019": "Análise Combinatória e Probabilidade",
        "Progressão, Enem 2018": "Progressões e Sequências",
        "Razão, proporção e Porcentagem, Enem 2019": "Razão, Proporção e Porcentagem",
        "Razão, proporção e Porcentagem, Enem PPL 2019": "Razão, Proporção e Porcentagem",
        "Razão, proporção e Porcentagem, Enem 2018": "Razão, Proporção e Porcentagem",
        "Razão e Proporção (Vest SP)": "Razão, Proporção e Porcentagem",
        "Sistema Binário ou Base 2": "Aritmética e Matemática Básica",
        "Polinomios": "Álgebra e Equações",
        "Polinomios: Divisão": "Álgebra e Equações",
        "Matrizes, Sistemas e Determinantes": "Álgebra Linear e Matrizes",
        "Equações (Vest SP)": "Álgebra e Equações",
        "Geografia Plana I": "Geometria Plana",
        "Geografia Plana II": "Geometria Plana",
        "Geografia Plana III": "Geometria Plana",
        "Análise Combinatória, Enem 2019": "Análise Combinatória e Probabilidade",
        "Análise Combinatória e Probabilidade, Enem PPL 2019": "Análise Combinatória e Probabilidade",
        "Análise Combinatória e Probabilidade, Enem 2018": "Análise Combinatória e Probabilidade",
        "Cônicas: (Elipse Hipérbole e Parábola)": "dropar",
        "Limite": "dropar",
        "Derivada": "dropar",
        "Integral": "dropar",
        "Limite, Derivada e Integral": "dropar",
    },
    "educacao-fisica": {
        "Educação Física": "dropar",
        "Práticas Corporais e Autonomia": "dropar",
        "Padrão Estético Contemporâneo": "dropar",
        "Esportes": "dropar",
        "Exercício Físico e Saúde": "dropar",
        "Corpo e Expressão Artística/Cultural": "dropar",
        "Danças": "dropar",
        "Condicionamentos e Esforços Físicos": "dropar",
        "Lutas": "dropar",
        "Jogos e Brincadeiras": "dropar",
    },
}

# Transformar o dict aninhado em uma lista de tuplas
data = [(c1, c2, val) for c1, inner in mappings.items() for c2, val in inner.items()]
map_df = pd.DataFrame(data, columns=["materia", "assunto", "novo_assunto"])

# %%
# Merge para trazer a coluna novo_valor
df = df.merge(map_df, on=["materia", "assunto"], how="left")
df["topico"] = df["novo_assunto"]

# %%
materias = df["materia"].unique()
for materia in materias:
    assuntos = df[df["materia"] == materia]["assunto"].unique()
    entradas = mappings[materia].keys()
    for assunto in assuntos:
        if assunto not in entradas:
            print(f"Falta mapear {materia} - {assunto}")

# %%
df = df[df['topico'] != 'dropar']
df[df['topico'] == 'dropar']
# Out:
# Empty DataFrame
# Columns: [materia, assunto, enunciado, alternativas, instituicao, novo_assunto, topico]
# Index: []

# %%
dups_total = df.duplicated(subset=["enunciado"], keep=False)
dups_total.sum()
# Out:
# np.int64(6337)

# %%
dups = df.duplicated(subset=["topico", "enunciado"], keep=False)
dups.sum()
# Out:
# np.int64(5028)

# %%
df = df.drop_duplicates(subset=["topico", "enunciado"], keep="first")
dups = df.duplicated(subset=["topico", "enunciado"], keep=False)
dups.sum()
# Out:
# np.int64(0)

# %%
x = 25  # limite mínimo de questões

total_antes = df.shape[0]
contagem = df["topico"].value_counts()
assuntos_raros = contagem[contagem < x]

# Filtrar o DataFrame para manter apenas os assuntos com contagem >= x
df = df[~df["topico"].isin(assuntos_raros.index)]

print("Assuntos dropados:")
print(assuntos_raros.index.tolist())
print(f"Total de questões dropadas: {total_antes - df.shape[0]}")
# Out:
# Assuntos dropados:
# ['Reprodução Humana', 'Vetores', 'Geografia Cultural', 'Logaritmos e Exponenciais', 'Tabela Periódica', 'Imunologia']
# Total de questões dropadas: 83

# %%
df_final = df[["materia", "topico", "enunciado", "alternativas"]].copy()
df_final.dropna(subset=["enunciado"], inplace=True)
df_final.to_parquet("./data/questoes_unificadas.parquet", index=False)
